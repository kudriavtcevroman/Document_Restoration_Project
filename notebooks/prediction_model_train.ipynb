# %%
# Шаг 1: Импорт библиотек и устройство
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import datasets, transforms, models
from torch.optim.lr_scheduler import CosineAnnealingLR
from torch.amp import autocast, GradScaler
import matplotlib.pyplot as plt
import numpy as np
from tqdm import tqdm
from sklearn.metrics import confusion_matrix, roc_curve, auc
import seaborn as sns
import os
from torch.nn.functional import softmax
from PIL import Image

device = torch.device('cuda:1')
print(f"Устройство: {device}")
# Out:
# Устройство: cuda:1

# %%
# Шаг 2: Трансформации (рабочее разрешение 1024×1448)
class PaddedResize:
    def __init__(self, size=(1024, 1448), div_factor=8):
        self.size = size
        self.div_factor = div_factor

    def __call__(self, img):
        img = transforms.Resize(self.size, interpolation=Image.LANCZOS)(img)
        w, h = img.size
        pad_w = (self.div_factor - w % self.div_factor) % self.div_factor
        pad_h = (self.div_factor - h % self.div_factor) % self.div_factor
        if pad_w or pad_h:
            img = transforms.Pad((0, 0, pad_w, pad_h), fill=0)(img)
        return img

train_transform = transforms.Compose([
    PaddedResize(size=(1024, 1448)),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2),
    transforms.RandomRotation(5),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

val_transform = transforms.Compose([
    PaddedResize(size=(1024, 1448)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# %%
# Шаг 3: Датасеты и DataLoader
dataset_path = '/home/user-4/Classified_Dataset'

train_dataset = datasets.ImageFolder(root=os.path.join(dataset_path, 'train'), transform=train_transform)
val_dataset   = datasets.ImageFolder(root=os.path.join(dataset_path, 'val'),   transform=val_transform)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, num_workers=4, pin_memory=True)
val_loader   = DataLoader(val_dataset,   batch_size=32, shuffle=False, num_workers=4, pin_memory=True)

print(f"Train: {len(train_dataset)} изображений")
print(f"Val:   {len(val_dataset)} изображений")
print(f"Классы: {train_dataset.class_to_idx}")
# Out:
# Train: 5670 изображений
# Val:   2430 изображений
# Классы: {'background': 0, 'bad_print': 1, 'brightness_contrast': 2, 'clean': 3, 'not_document': 4, 'pixelation': 5}

# %%
# Шаг 4: Модель ResNet50 (6 классов)
model = models.resnet50(pretrained=True)
num_ftrs = model.fc.in_features
model.fc = nn.Sequential(
    nn.Dropout(0.5),
    nn.Linear(num_ftrs, 6)   # 6 классов
)
model = model.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.AdamW(model.parameters(), lr=1e-4, weight_decay=1e-4)
scheduler = CosineAnnealingLR(optimizer, T_max=200, eta_min=1e-6)
scaler = GradScaler()

# Early stopping
patience = 15
early_stop_counter = 0
best_val_acc = 0.0

# Папка для чекпоинтов
os.makedirs('checkpoints', exist_ok=True)

train_losses, val_losses = [], []
train_accs, val_accs = [], []
# Out:
# /home/user-4/env/lib/python3.12/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/user-4/env/lib/python3.12/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
# Шаг 5: Цикл обучения (200 эпох)
num_epochs = 200

for epoch in range(num_epochs):
    model.train()
    train_loss = train_correct = 0

    for inputs, labels in tqdm(train_loader, desc=f"Epoch {epoch+1}/{num_epochs} [train]"):
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad()
        with autocast(device_type='cuda'):
            outputs = model(inputs)
            loss = criterion(outputs, labels)
        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()
        train_loss += loss.item() * inputs.size(0)
        train_correct += (outputs.argmax(1) == labels).sum().item()

    avg_train_loss = train_loss / len(train_dataset)
    avg_train_acc = train_correct / len(train_dataset)
    train_losses.append(avg_train_loss)
    train_accs.append(avg_train_acc)

    # Валидация
    model.eval()
    val_loss = val_correct = 0
    all_preds, all_labels, all_probs = [], [], []

    with torch.no_grad():
        for inputs, labels in tqdm(val_loader, desc=f"Epoch {epoch+1}/{num_epochs} [val]"):
            inputs, labels = inputs.to(device), labels.to(device)
            with autocast(device_type='cuda'):
                outputs = model(inputs)
                loss = criterion(outputs, labels)
            val_loss += loss.item() * inputs.size(0)
            val_correct += (outputs.argmax(1) == labels).sum().item()
            probs = softmax(outputs, dim=1)
            all_preds.extend(outputs.argmax(1).cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
            all_probs.extend(probs.cpu().numpy())

    avg_val_loss = val_loss / len(val_dataset)
    avg_val_acc = val_correct / len(val_dataset)
    val_losses.append(avg_val_loss)
    val_accs.append(avg_val_acc)

    scheduler.step()

    print(f"Эпоха {epoch+1}/{num_epochs} | Train Loss: {avg_train_loss:.4f} | Train Acc: {avg_train_acc:.4f} | "
          f"Val Loss: {avg_val_loss:.4f} | Val Acc: {avg_val_acc:.4f}")

    # Сохранение чекпоинта каждой эпохи
    torch.save(model.state_dict(), f"checkpoints/prediction_model_ep{epoch+1}.pth")

    # Early stopping + сохранение лучшей модели
    if avg_val_acc > best_val_acc:
        best_val_acc = avg_val_acc
        torch.save(model.state_dict(), "prediction_model.pth")
        print("→ Новая лучшая модель сохранена как prediction_model.pth")
        early_stop_counter = 0
    else:
        early_stop_counter += 1
        if early_stop_counter >= patience:
            print("Early stopping сработал")
            break
# Out:
# ...
# Epoch 1/200 [val]: 100%|██████████| 76/76 [00:46<00:00,  1.63it/s]
# Эпоха 1/200 | Train Loss: 0.1062 | Train Acc: 0.9683 | Val Loss: 0.0321 | Val Acc: 0.9901
# → Новая лучшая модель сохранена как prediction_model.pth
# Epoch 2/200 [train]:  84%|████████▍ | 150/178 [02:11<00:24,  1.14it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 15
#      13     loss = criterion(outputs, labels)
#      14 scaler.scale(loss).backward()
# ---> 15 scaler.step(optimizer)
#      16 scaler.update()
#      17 train_loss += loss.item() * inputs.size(0)
#
# File ~/env/lib/python3.12/site-packages/torch/amp/grad_scaler.py:461, in GradScaler.step(self, optimizer, *args, **kwargs)
#     455     self.unscale_(optimizer)
#     457 assert (
#     458     len(optimizer_state["found_inf_per_device"]) > 0
#     459 ), "No inf checks were recorded for this optimizer."
# ...
